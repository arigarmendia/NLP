# %% [markdown]
# <img src="https://github.com/hernancontigiani/ceia_memorias_especializacion/raw/master/Figures/logoFIUBA.jpg" width="500" align="center">
#
#
# # Procesamiento de lenguaje natural
# ## LSTM Bot QA

# %% [markdown]
# ### Datos
# El objecto es utilizar datos disponibles del challenge ConvAI2 (Conversational Intelligence Challenge 2) de conversaciones en inglés. Se construirá un BOT para responder a preguntas del usuario (QA).\
# [LINK](http://convai.io/data/)

# %%
#!pip install --upgrade --no-cache-dir gdown --quiet

# %%
import re

import numpy as np
import pandas as pd

import tensorflow as tf
from keras.preprocessing.text import one_hot
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers.core import Activation, Dropout, Dense
from keras.layers import Flatten, LSTM, SimpleRNN
from keras.models import Model
from keras.layers import Embedding
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from keras.layers import Input

# %%
# Descargar la carpeta de dataset
import os
import gdown
if os.access('data_volunteers.json', os.F_OK) is False:
    url = 'https://drive.google.com/uc?id=1awUxYwImF84MIT5-jCaYAPe2QwSgS1hN&export=download'
    output = 'data_volunteers.json'
    gdown.download(url, output, quiet=False)
else:
    print("El dataset ya se encuentra descargado")
# Out:
# El dataset ya se encuentra descargado

# %%
# dataset_file
import json

text_file = "data_volunteers.json"
with open(text_file) as f:
    data = json.load(f) # la variable data será un diccionario

# %%
# Observar los campos disponibles en cada linea del dataset
data[0].keys()
# Out:
# dict_keys(['dialog', 'start_time', 'end_time', 'bot_profile', 'user_profile', 'eval_score', 'profile_match', 'participant1_id', 'participant2_id'])

# %%
chat_in = []
chat_out = []

input_sentences = []
output_sentences = []
output_sentences_inputs = []
max_len = 30

def clean_text(txt):
    txt = txt.lower()    
    txt.replace("\'d", " had")
    txt.replace("\'s", " is")
    txt.replace("\'m", " am")
    txt.replace("don't", "do not")
    txt = re.sub(r'\W+', ' ', txt)
    
    return txt

for line in data:
    for i in range(len(line['dialog'])-1):
        # vamos separando el texto en "preguntas" (chat_in)
        # y "respuestas" (chat_out)
        chat_in = clean_text(line['dialog'][i]['text'])
        chat_out = clean_text(line['dialog'][i+1]['text'])

        if len(chat_in) >= max_len or len(chat_out) >= max_len:
            continue

        input_sentence, output = chat_in, chat_out
        
        # output sentence (decoder_output) tiene <eos>
        output_sentence = output + ' <eos>'
        # output sentence input (decoder_input) tiene <sos>
        output_sentence_input = '<sos> ' + output

        input_sentences.append(input_sentence)
        output_sentences.append(output_sentence)
        output_sentences_inputs.append(output_sentence_input)

print("Cantidad de rows utilizadas:", len(input_sentences))
# Out:
# Cantidad de rows utilizadas: 6033

# %%
input_sentences[1], output_sentences[1], output_sentences_inputs[1]
# Out:
# ('hi how are you ', 'not bad and you  <eos>', '<sos> not bad and you ')

# %%
input_sentences[0:5], output_sentences[0:5], output_sentences_inputs[0:5]
# Out:
# (['hello ', 'hi how are you ', 'hi ', 'hi ', 'hi '],
#  ['hi how are you  <eos>',
#   'not bad and you  <eos>',
#   'hello  <eos>',
#   'hello  <eos>',
#   'hello how are you today  <eos>'],
#  ['<sos> hi how are you ',
#   '<sos> not bad and you ',
#   '<sos> hello ',
#   '<sos> hello ',
#   '<sos> hello how are you today '])

# %% [markdown]
# ### 2 - Preprocesamiento
# Realizar el preprocesamiento necesario para obtener:
# - word2idx_inputs, max_input_len
# - word2idx_outputs, max_out_len, num_words_output
# - encoder_input_sequences, decoder_output_sequences, decoder_targets

# %%
# Definir el tamaño máximo del vocabulario
MAX_VOCAB_SIZE = 8000

# %%
# Tokenizar las palabras con el Tokenizer de Keras
# Definir una máxima cantidad de palabras a utilizar:
# - num_words --> the maximum number of words to keep, based on word frequency.
# - Only the most common num_words-1 words will be kept.
from keras.preprocessing.text import Tokenizer
input_tokenizer = Tokenizer(num_words=MAX_VOCAB_SIZE)
input_tokenizer.fit_on_texts(input_sentences)
input_integer_seq = input_tokenizer.texts_to_sequences(input_sentences)

word2idx_inputs = input_tokenizer.word_index
print("Palabras en el vocabulario:", len(word2idx_inputs))

max_input_len = max(len(sen) for sen in input_integer_seq)
print("Sentencia de entrada más larga:", max_input_len)
# Out:
# Palabras en el vocabulario: 1799
# Sentencia de entrada más larga: 9

# %%
# A los filtros de símbolos del Tokenizer agregamos el "¿",
# sacamos los "<>" para que no afectar nuestros tokens
output_tokenizer = Tokenizer(num_words=MAX_VOCAB_SIZE, filters='!"#$%&()*+,-./:;=¿?@[\\]^_`{|}~\t\n')
output_tokenizer.fit_on_texts(["<sos>", "<eos>"] + output_sentences)

output_integer_seq = output_tokenizer.texts_to_sequences(output_sentences)

output_input_integer_seq = output_tokenizer.texts_to_sequences(output_sentences_inputs)

word2idx_outputs = output_tokenizer.word_index
print("Palabras en el vocabulario:", len(word2idx_outputs))

num_words_output = min(len(word2idx_outputs) + 1, MAX_VOCAB_SIZE) 
# Se suma 1 para incluir el token de palabra desconocida

max_out_len = max(len(sen) for sen in output_integer_seq)
print("Sentencia de salida más larga:", max_out_len)
# Out:
# Palabras en el vocabulario: 1806
# Sentencia de salida más larga: 10

# %%
# Por una cuestion de que no explote la RAM se limitará el tamaño de las sentencias de entrada
# a la mitad:
#max_input_len = 16
#max_out_len = 18

# %%
print("Cantidad de rows del dataset:", len(input_integer_seq))

encoder_input_sequences = pad_sequences(input_integer_seq, maxlen=max_input_len)
print("encoder_input_sequences shape:", encoder_input_sequences.shape)

decoder_input_sequences = pad_sequences(output_input_integer_seq, maxlen=max_out_len, padding='post')
print("decoder_input_sequences shape:", decoder_input_sequences.shape)
# Out:
# Cantidad de rows del dataset: 6033
# encoder_input_sequences shape: (6033, 9)
# decoder_input_sequences shape: (6033, 10)

# %%
from keras.utils.np_utils import to_categorical
decoder_output_sequences = pad_sequences(output_integer_seq, maxlen=max_out_len, padding='post')
decoder_targets = to_categorical(decoder_output_sequences, num_classes=num_words_output)
decoder_targets.shape
# Out:
# (6033, 10, 1807)

# %% [markdown]
# ### 3 - Preparar los embeddings
# Utilizar los embeddings de Glove o FastText para transformar los tokens de entrada en vectores

# %%
import logging
import os
from pathlib import Path
from io import StringIO
import pickle

class WordsEmbeddings(object):
    logger = logging.getLogger(__name__)

    def __init__(self):
        # load the embeddings
        words_embedding_pkl = Path(self.PKL_PATH)
        if not words_embedding_pkl.is_file():
            words_embedding_txt = Path(self.WORD_TO_VEC_MODEL_TXT_PATH)
            assert words_embedding_txt.is_file(), 'Words embedding not available'
            embeddings = self.convert_model_to_pickle()
        else:
            embeddings = self.load_model_from_pickle()
        self.embeddings = embeddings
        # build the vocabulary hashmap
        index = np.arange(self.embeddings.shape[0])
        # Dicctionarios para traducir de embedding a IDX de la palabra
        self.word2idx = dict(zip(self.embeddings['word'], index))
        self.idx2word = dict(zip(index, self.embeddings['word']))

    def get_words_embeddings(self, words):
        words_idxs = self.words2idxs(words)
        return self.embeddings[words_idxs]['embedding']

    def words2idxs(self, words):
        return np.array([self.word2idx.get(word, -1) for word in words])

    def idxs2words(self, idxs):
        return np.array([self.idx2word.get(idx, '-1') for idx in idxs])

    def load_model_from_pickle(self):
        self.logger.debug(
            'loading words embeddings from pickle {}'.format(
                self.PKL_PATH
            )
        )
        max_bytes = 2**28 - 1 # 256MB
        bytes_in = bytearray(0)
        input_size = os.path.getsize(self.PKL_PATH)
        with open(self.PKL_PATH, 'rb') as f_in:
            for _ in range(0, input_size, max_bytes):
                bytes_in += f_in.read(max_bytes)
        embeddings = pickle.loads(bytes_in)
        self.logger.debug('words embeddings loaded')
        return embeddings

    def convert_model_to_pickle(self):
        # create a numpy strctured array:
        # word     embedding
        # U50      np.float32[]
        # word_1   a, b, c
        # word_2   d, e, f
        # ...
        # word_n   g, h, i
        self.logger.debug(
            'converting and loading words embeddings from text file {}'.format(
                self.WORD_TO_VEC_MODEL_TXT_PATH
            )
        )
        structure = [('word', np.dtype('U' + str(self.WORD_MAX_SIZE))),
                     ('embedding', np.float32, (self.N_FEATURES,))]
        structure = np.dtype(structure)
        # load numpy array from disk using a generator
        with open(self.WORD_TO_VEC_MODEL_TXT_PATH, encoding="utf8") as words_embeddings_txt:
            embeddings_gen = (
                (line.split()[0], line.split()[1:]) for line in words_embeddings_txt
                if len(line.split()[1:]) == self.N_FEATURES
            )
            embeddings = np.fromiter(embeddings_gen, structure)
        # add a null embedding
        null_embedding = np.array(
            [('null_embedding', np.zeros((self.N_FEATURES,), dtype=np.float32))],
            dtype=structure
        )
        embeddings = np.concatenate([embeddings, null_embedding])
        # dump numpy array to disk using pickle
        max_bytes = 2**28 - 1 # # 256MB
        bytes_out = pickle.dumps(embeddings, protocol=pickle.HIGHEST_PROTOCOL)
        with open(self.PKL_PATH, 'wb') as f_out:
            for idx in range(0, len(bytes_out), max_bytes):
                f_out.write(bytes_out[idx:idx+max_bytes])
        self.logger.debug('words embeddings loaded')
        return embeddings


class GloveEmbeddings(WordsEmbeddings):
    WORD_TO_VEC_MODEL_TXT_PATH = 'glove.twitter.27B.50d.txt'
    PKL_PATH = 'gloveembedding.pkl'
    N_FEATURES = 50
    WORD_MAX_SIZE = 60

class FasttextEmbeddings(WordsEmbeddings):
    WORD_TO_VEC_MODEL_TXT_PATH = 'cc.en.300.vec'
    PKL_PATH = 'fasttext.pkl'
    N_FEATURES = 300
    WORD_MAX_SIZE = 60

# %%
# Se utilizarán los embeddings de Fasttext
model_embeddings = FasttextEmbeddings()

# %%
# Crear la Embedding matrix de las secuencias
# en inglés

print('preparing embedding matrix...')
embed_dim = model_embeddings.N_FEATURES
words_not_found = []

# word_index provieen del tokenizer

nb_words = min(MAX_VOCAB_SIZE, len(word2idx_inputs)) # vocab_size
embedding_matrix = np.zeros((nb_words, embed_dim))
for word, i in word2idx_inputs.items():
    if i >= nb_words:
        continue
    embedding_vector = model_embeddings.get_words_embeddings(word)[0]
    if (embedding_vector is not None) and len(embedding_vector) > 0:
        
        embedding_matrix[i] = embedding_vector
    else:
        # words not found in embedding index will be all-zeros.
        words_not_found.append(word)

print('number of null word embeddings:', np.sum(np.sum(embedding_matrix, axis=1) == 0))
# Out:
# preparing embedding matrix...
# number of null word embeddings: 1

# %%
# Dimensión de los embeddings
embedding_matrix.shape
# Out:
# (1799, 300)

# %% [markdown]
# ### 4 - Entrenar el modelo
# Entrenar un modelo basado en el esquema encoder-decoder utilizando los datos generados en los puntos anteriores. Utilce como referencias los ejemplos vistos en clase.

# %%
from keras.models import Model
from keras.layers import Input, LSTM, Dense, Dropout, Bidirectional, Embedding

n_units = 128

# define training encoder
encoder_inputs = Input(shape=(max_input_len))

#encoder_embedding_layer = Embedding(num_words, EMBEDDING_SIZE, weights=[embedding_matrix], input_length=max_input_len)

encoder_embedding_layer = Embedding(
          input_dim=nb_words,  # definido en el Tokenizador
          output_dim=embed_dim,  # dimensión de los embeddings utilizados
          input_length=max_input_len, # máxima sentencia de entrada
          weights=[embedding_matrix],  # matrix de embeddings
          trainable=False)      # marcar como layer no entrenable

encoder_inputs_x = encoder_embedding_layer(encoder_inputs)

encoder = LSTM(n_units, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs_x)
encoder_states = [state_h, state_c]

# define training decoder
decoder_inputs = Input(shape=(max_out_len))
decoder_embedding_layer = Embedding(input_dim=num_words_output, output_dim=n_units, input_length=max_out_len)
decoder_inputs_x = decoder_embedding_layer(decoder_inputs)

decoder_lstm = LSTM(n_units, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs_x, initial_state=encoder_states)

# Dense
decoder_dense = Dense(num_words_output, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)


model = Model([encoder_inputs, decoder_inputs], decoder_outputs)



model.compile(loss='categorical_crossentropy', optimizer="Adam", metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 9)]          0           []
#
#  input_7 (InputLayer)           [(None, 10)]         0           []
#
#  embedding_2 (Embedding)        (None, 9, 300)       539700      ['input_6[0][0]']
#
#  embedding_3 (Embedding)        (None, 10, 128)      231296      ['input_7[0][0]']
#
#  lstm_2 (LSTM)                  [(None, 128),        219648      ['embedding_2[0][0]']
#                                  (None, 128),
#                                  (None, 128)]
#
#  lstm_3 (LSTM)                  [(None, 10, 128),    131584      ['embedding_3[0][0]',
#                                  (None, 128),                     'lstm_2[0][1]',
#                                  (None, 128)]                     'lstm_2[0][2]']
#
#  dense_1 (Dense)                (None, 10, 1807)     233103      ['lstm_3[0][0]']
#
# ==================================================================================================
# Total params: 1,355,331
# Trainable params: 815,631
# Non-trainable params: 539,700
# __________________________________________________________________________________________________

# %%
# Modelo completo (encoder+decoder) para poder entrenar
from keras.utils.vis_utils import plot_model
plot_model(model, show_shapes=True, show_layer_names=True)

# %%
# Modelo solo encoder

# define inference encoder
encoder_model = Model(encoder_inputs, encoder_states)

from keras.utils.vis_utils import plot_model
plot_model(encoder_model, show_shapes=True, show_layer_names=True)

# %%
# Modelo solo decoder (para realizar inferencia)
from keras.utils.vis_utils import plot_model

# define inference decoder
decoder_state_input_h = Input(shape=(n_units,))
decoder_state_input_c = Input(shape=(n_units,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

# En cada predicción habrá una sola palabra de entrada al decoder,
# que es la realimentación de la palabra anterior
# por lo que hay que modificar el input shape de la layer de Embedding
decoder_inputs_single = Input(shape=(1,))
decoder_inputs_single_x = decoder_embedding_layer(decoder_inputs_single)

decoder_outputs, state_h, state_c = decoder_lstm(decoder_inputs_single_x, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]

decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model([decoder_inputs_single] + decoder_states_inputs, [decoder_outputs] + decoder_states)

plot_model(decoder_model, show_shapes=True, show_layer_names=True)

# %%
hist = model.fit(
    [encoder_input_sequences, decoder_input_sequences],
    decoder_targets,
    epochs=80, 
    validation_split=0.2)
# Out:
# Epoch 1/80
# 2022-12-03 17:40:42.653294: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2022-12-03 17:40:42.900658: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2022-12-03 17:40:42.948892: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2022-12-03 17:40:43.027477: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#   5/151 [..............................] - ETA: 3s - loss: 7.4457 - accuracy: 0.4025
# 2022-12-03 17:40:43.102955: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 151/151 [==============================] - ETA: 0s - loss: 3.0356 - accuracy: 0.5379
# 2022-12-03 17:40:46.795206: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2022-12-03 17:40:46.893329: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2022-12-03 17:40:46.933633: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 151/151 [==============================] - 6s 28ms/step - loss: 3.0356 - accuracy: 0.5379 - val_loss: 2.2560 - val_accuracy: 0.6279
# Epoch 2/80
# 151/151 [==============================] - 3s 22ms/step - loss: 2.0566 - accuracy: 0.6244 - val_loss: 2.0984 - val_accuracy: 0.6517
# Epoch 3/80
# 151/151 [==============================] - 3s 22ms/step - loss: 1.8361 - accuracy: 0.6752 - val_loss: 1.9480 - val_accuracy: 0.6896
# Epoch 4/80
# 151/151 [==============================] - 3s 22ms/step - loss: 1.6563 - accuracy: 0.7125 - val_loss: 1.8499 - val_accuracy: 0.6997
# Epoch 5/80
# 151/151 [==============================] - 3s 22ms/step - loss: 1.5321 - accuracy: 0.7259 - val_loss: 1.7916 - val_accuracy: 0.7044
# Epoch 6/80
# 151/151 [==============================] - 3s 22ms/step - loss: 1.4509 - accuracy: 0.7343 - val_loss: 1.7490 - val_accuracy: 0.7122
# Epoch 7/80
# 151/151 [==============================] - 3s 22ms/step - loss: 1.3892 - accuracy: 0.7414 - val_loss: 1.7168 - val_accuracy: 0.7147
# Epoch 8/80
# 151/151 [==============================] - 3s 22ms/step - loss: 1.3367 - accuracy: 0.7466 - val_loss: 1.7014 - val_accuracy: 0.7200
# Epoch 9/80
# 151/151 [==============================] - 3s 22ms/step - loss: 1.2918 - accuracy: 0.7511 - val_loss: 1.6823 - val_accuracy: 0.7197
# Epoch 10/80
# 151/151 [==============================] - 3s 22ms/step - loss: 1.2527 - accuracy: 0.7543 - val_loss: 1.6647 - val_accuracy: 0.7220
# Epoch 11/80
# 151/151 [==============================] - 3s 22ms/step - loss: 1.2181 - accuracy: 0.7590 - val_loss: 1.6606 - val_accuracy: 0.7255
# Epoch 12/80
# 151/151 [==============================] - 3s 22ms/step - loss: 1.1859 - accuracy: 0.7625 - val_loss: 1.6510 - val_accuracy: 0.7264
# Epoch 13/80
# 151/151 [==============================] - 3s 22ms/step - loss: 1.1591 - accuracy: 0.7652 - val_loss: 1.6479 - val_accuracy: 0.7251
# Epoch 14/80
# 151/151 [==============================] - 3s 22ms/step - loss: 1.1321 - accuracy: 0.7687 - val_loss: 1.6417 - val_accuracy: 0.7266
# Epoch 15/80
# 151/151 [==============================] - 3s 22ms/step - loss: 1.1078 - accuracy: 0.7706 - val_loss: 1.6473 - val_accuracy: 0.7297
# Epoch 16/80
# 151/151 [==============================] - 3s 23ms/step - loss: 1.0858 - accuracy: 0.7734 - val_loss: 1.6377 - val_accuracy: 0.7289
# Epoch 17/80
# 151/151 [==============================] - 4s 24ms/step - loss: 1.0633 - accuracy: 0.7754 - val_loss: 1.6428 - val_accuracy: 0.7302
# Epoch 18/80
# 151/151 [==============================] - 4s 24ms/step - loss: 1.0428 - accuracy: 0.7781 - val_loss: 1.6441 - val_accuracy: 0.7302
# Epoch 19/80
# 151/151 [==============================] - 4s 24ms/step - loss: 1.0236 - accuracy: 0.7784 - val_loss: 1.6437 - val_accuracy: 0.7334
# Epoch 20/80
# 151/151 [==============================] - 4s 24ms/step - loss: 1.0052 - accuracy: 0.7816 - val_loss: 1.6442 - val_accuracy: 0.7341
# Epoch 21/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.9857 - accuracy: 0.7830 - val_loss: 1.6476 - val_accuracy: 0.7342
# Epoch 22/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.9680 - accuracy: 0.7854 - val_loss: 1.6540 - val_accuracy: 0.7322
# Epoch 23/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.9507 - accuracy: 0.7877 - val_loss: 1.6571 - val_accuracy: 0.7335
# Epoch 24/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.9341 - accuracy: 0.7902 - val_loss: 1.6629 - val_accuracy: 0.7345
# Epoch 25/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.9171 - accuracy: 0.7929 - val_loss: 1.6672 - val_accuracy: 0.7361
# Epoch 26/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.9015 - accuracy: 0.7956 - val_loss: 1.6681 - val_accuracy: 0.7338
# Epoch 27/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.8866 - accuracy: 0.7981 - val_loss: 1.6762 - val_accuracy: 0.7344
# Epoch 28/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.8717 - accuracy: 0.8010 - val_loss: 1.6785 - val_accuracy: 0.7334
# Epoch 29/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.8563 - accuracy: 0.8023 - val_loss: 1.6862 - val_accuracy: 0.7332
# Epoch 30/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.8424 - accuracy: 0.8046 - val_loss: 1.6898 - val_accuracy: 0.7348
# Epoch 31/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.8288 - accuracy: 0.8063 - val_loss: 1.6975 - val_accuracy: 0.7341
# Epoch 32/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.8144 - accuracy: 0.8099 - val_loss: 1.7034 - val_accuracy: 0.7354
# Epoch 33/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.8021 - accuracy: 0.8113 - val_loss: 1.7103 - val_accuracy: 0.7323
# Epoch 34/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.7892 - accuracy: 0.8129 - val_loss: 1.7212 - val_accuracy: 0.7340
# Epoch 35/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.7759 - accuracy: 0.8157 - val_loss: 1.7311 - val_accuracy: 0.7336
# Epoch 36/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.7644 - accuracy: 0.8169 - val_loss: 1.7317 - val_accuracy: 0.7314
# Epoch 37/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.7521 - accuracy: 0.8191 - val_loss: 1.7397 - val_accuracy: 0.7327
# Epoch 38/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.7397 - accuracy: 0.8216 - val_loss: 1.7464 - val_accuracy: 0.7313
# Epoch 39/80
# 151/151 [==============================] - 3s 23ms/step - loss: 0.7288 - accuracy: 0.8237 - val_loss: 1.7575 - val_accuracy: 0.7335
# Epoch 40/80
# 151/151 [==============================] - 3s 23ms/step - loss: 0.7174 - accuracy: 0.8250 - val_loss: 1.7636 - val_accuracy: 0.7316
# Epoch 41/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.7063 - accuracy: 0.8275 - val_loss: 1.7751 - val_accuracy: 0.7336
# Epoch 42/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.6945 - accuracy: 0.8296 - val_loss: 1.7850 - val_accuracy: 0.7330
# Epoch 43/80
# 151/151 [==============================] - 3s 23ms/step - loss: 0.6841 - accuracy: 0.8306 - val_loss: 1.7927 - val_accuracy: 0.7312
# Epoch 44/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.6746 - accuracy: 0.8326 - val_loss: 1.8019 - val_accuracy: 0.7312
# Epoch 45/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.6639 - accuracy: 0.8346 - val_loss: 1.8059 - val_accuracy: 0.7305
# Epoch 46/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.6533 - accuracy: 0.8367 - val_loss: 1.8190 - val_accuracy: 0.7311
# Epoch 47/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.6433 - accuracy: 0.8386 - val_loss: 1.8279 - val_accuracy: 0.7310
# Epoch 48/80
# 151/151 [==============================] - 3s 23ms/step - loss: 0.6328 - accuracy: 0.8407 - val_loss: 1.8408 - val_accuracy: 0.7315
# Epoch 49/80
# 151/151 [==============================] - 3s 23ms/step - loss: 0.6242 - accuracy: 0.8434 - val_loss: 1.8474 - val_accuracy: 0.7299
# Epoch 50/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.6134 - accuracy: 0.8449 - val_loss: 1.8648 - val_accuracy: 0.7306
# Epoch 51/80
# 151/151 [==============================] - 3s 23ms/step - loss: 0.6040 - accuracy: 0.8481 - val_loss: 1.8743 - val_accuracy: 0.7307
# Epoch 52/80
# 151/151 [==============================] - 3s 23ms/step - loss: 0.5944 - accuracy: 0.8499 - val_loss: 1.8859 - val_accuracy: 0.7295
# Epoch 53/80
# 151/151 [==============================] - 4s 24ms/step - loss: 0.5856 - accuracy: 0.8509 - val_loss: 1.8960 - val_accuracy: 0.7285
# Epoch 54/80
# 151/151 [==============================] - 3s 23ms/step - loss: 0.5753 - accuracy: 0.8538 - val_loss: 1.9028 - val_accuracy: 0.7280
# Epoch 55/80
# 151/151 [==============================] - 3s 23ms/step - loss: 0.5669 - accuracy: 0.8561 - val_loss: 1.9116 - val_accuracy: 0.7281
# Epoch 56/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.5578 - accuracy: 0.8581 - val_loss: 1.9274 - val_accuracy: 0.7261
# Epoch 57/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.5479 - accuracy: 0.8607 - val_loss: 1.9370 - val_accuracy: 0.7278
# Epoch 58/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.5406 - accuracy: 0.8620 - val_loss: 1.9426 - val_accuracy: 0.7278
# Epoch 59/80
# 151/151 [==============================] - 3s 23ms/step - loss: 0.5311 - accuracy: 0.8642 - val_loss: 1.9550 - val_accuracy: 0.7254
# Epoch 60/80
# 151/151 [==============================] - 3s 23ms/step - loss: 0.5233 - accuracy: 0.8658 - val_loss: 1.9648 - val_accuracy: 0.7262
# Epoch 61/80
# 151/151 [==============================] - 4s 24ms/step - loss: 0.5154 - accuracy: 0.8687 - val_loss: 1.9823 - val_accuracy: 0.7250
# Epoch 62/80
# 151/151 [==============================] - 3s 23ms/step - loss: 0.5068 - accuracy: 0.8702 - val_loss: 1.9885 - val_accuracy: 0.7259
# Epoch 63/80
# 151/151 [==============================] - 4s 25ms/step - loss: 0.4980 - accuracy: 0.8727 - val_loss: 1.9989 - val_accuracy: 0.7250
# Epoch 64/80
# 151/151 [==============================] - 4s 25ms/step - loss: 0.4909 - accuracy: 0.8738 - val_loss: 2.0149 - val_accuracy: 0.7258
# Epoch 65/80
# 151/151 [==============================] - 3s 23ms/step - loss: 0.4826 - accuracy: 0.8759 - val_loss: 2.0316 - val_accuracy: 0.7232
# Epoch 66/80
# 151/151 [==============================] - 3s 23ms/step - loss: 0.4751 - accuracy: 0.8782 - val_loss: 2.0358 - val_accuracy: 0.7239
# Epoch 67/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.4674 - accuracy: 0.8793 - val_loss: 2.0470 - val_accuracy: 0.7244
# Epoch 68/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.4598 - accuracy: 0.8817 - val_loss: 2.0640 - val_accuracy: 0.7242
# Epoch 69/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.4539 - accuracy: 0.8826 - val_loss: 2.0740 - val_accuracy: 0.7238
# Epoch 70/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.4468 - accuracy: 0.8837 - val_loss: 2.0797 - val_accuracy: 0.7234
# Epoch 71/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.4392 - accuracy: 0.8861 - val_loss: 2.0928 - val_accuracy: 0.7243
# Epoch 72/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.4318 - accuracy: 0.8884 - val_loss: 2.1023 - val_accuracy: 0.7248
# Epoch 73/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.4258 - accuracy: 0.8896 - val_loss: 2.1202 - val_accuracy: 0.7236
# Epoch 74/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.4196 - accuracy: 0.8920 - val_loss: 2.1319 - val_accuracy: 0.7232
# Epoch 75/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.4128 - accuracy: 0.8939 - val_loss: 2.1423 - val_accuracy: 0.7216
# Epoch 76/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.4071 - accuracy: 0.8939 - val_loss: 2.1575 - val_accuracy: 0.7225
# Epoch 77/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.4006 - accuracy: 0.8961 - val_loss: 2.1628 - val_accuracy: 0.7200
# Epoch 78/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.3959 - accuracy: 0.8974 - val_loss: 2.1674 - val_accuracy: 0.7198
# Epoch 79/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.3880 - accuracy: 0.8997 - val_loss: 2.1857 - val_accuracy: 0.7234
# Epoch 80/80
# 151/151 [==============================] - 3s 22ms/step - loss: 0.3826 - accuracy: 0.9005 - val_loss: 2.1973 - val_accuracy: 0.7203

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Entrenamiento
epoch_count = range(1, len(hist.history['accuracy']) + 1)
sns.lineplot(x=epoch_count,  y=hist.history['loss'], label='train')
sns.lineplot(x=epoch_count,  y=hist.history['val_loss'], label='valid')
plt.title('Loss')
plt.show()
sns.lineplot(x=epoch_count,  y=hist.history['accuracy'], label='train')
sns.lineplot(x=epoch_count,  y=hist.history['val_accuracy'], label='valid')
plt.title('Accuracy')
plt.show()

# %% [markdown]
# ### 5 - Inferencia
# Experimentar el funcionamiento de su modelo. Recuerde que debe realizar la inferencia de los modelos por separado de encoder y decoder.

# %%
# Armar los conversores de índice a palabra:
idx2word_input = {v:k for k, v in word2idx_inputs.items()}
idx2word_target = {v:k for k, v in word2idx_outputs.items()}

# %%
def get_response(input_seq):
    # Se transforma la sequencia de entrada a los estados "h" y "c" de la LSTM
    # para enviar la primera vez al decoder
    states_value = encoder_model.predict(input_seq)

    # Se inicializa la secuencia de entrada al decoder como "<sos>"
    target_seq = np.zeros((1, 1))
    target_seq[0, 0] = word2idx_outputs['<sos>']

    # Se obtiene el índice que finaliza la inferencia
    eos = word2idx_outputs['<eos>']
    
    output_sentence = []
    for _ in range(max_out_len):
        # Predicción del próximo elemento
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)
        idx = np.argmax(output_tokens[0, 0, :])

        # Si es "end of sentece <eos>" se acaba
        if eos == idx:
            break

        # Transformar idx a palabra
        word = ''        
        if idx > 0:
            word = idx2word_target[idx]
            output_sentence.append(word)

        # Actualizar los estados dada la última predicción
        states_value = [h, c]

        # Actualizar secuencia de entrada con la salida (re-alimentación)
        target_seq[0, 0] = idx

    return ' '.join(output_sentence)

# %%
i = np.random.choice(len(input_sentences))
input_seq = encoder_input_sequences[i:i+1]
response = get_response(input_seq)
print('-')
print('Input:', input_sentences[i])
print('Response:', response)
# Out:
# 2022-12-03 17:45:15.812095: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2022-12-03 17:45:15.983728: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 1s 1s/step
# 2022-12-03 17:45:16.973513: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2022-12-03 17:45:17.106020: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 1s 676ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# -
# Input: veg it is my favorite
# Response: i am not sure what you mean

# %%
def test_model(input_text):
    for q in input_text:
        integer_seq_test = input_tokenizer.texts_to_sequences([q])[0]
        encoder_sequence_test = pad_sequences([integer_seq_test], maxlen=max_input_len)
        print('Input:', q)
        response = get_response(encoder_sequence_test)
        print('Response:', response)

# %%
input_text = ['hi', 'how are you?', "where are you from?", 
            'where do you live?', "what do you do for a living?", 
            'do you have any hobbies?','what do you do for fun?', 
            "what is your favorite food?",'where are you from?', 
            'what do you study?','what is your name?', 
            'do you have pets?', 'do you like music?',
            'what is your favorite colour?']

# %%
test_model(input_text)
# Out:
# Input: hi
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# Response: hello how are you
# Input: how are you?
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# Response: i am doing well how are you
# Input: where are you from?
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Response: i am from the united states
# Input: where do you live?
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# Response: i like to play video games
# Input: what do you do for a living?
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# Response: i m a student
# Input: do you have any hobbies?
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# Response: i like to read and read
# Input: what do you do for fun?
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# Response: i do not like it
# Input: what is your favorite food?
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# Response: bred and vegetables
# Input: where are you from?
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# Response: i am from the united states
# Input: what do you study?
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# Response: degree
# Input: what is your name?
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# Response: what is your name
# Input: do you have pets?
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# Response: i do not have any
# Input: do you like music?
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# Response: do you like
# Input: what is your favorite colour?
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# Response: i like to read books

# %% [markdown]
# #### Se observa que el modelo presenta overfitting pero en general los resultados fueron bastante buenos ya que el bot responde correctamente aproximadamente la mitad de las preguntas.
